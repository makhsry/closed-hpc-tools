# %%
def go_to_my_drive():
  from google.colab import drive
  drive.mount('/content/gdrive/')

# %%
def go_to_my_desktop():
  # %cd /content/gdrive/MyDrive/LMP2

# %%
def download_lammps_from_source():
  # !git clone -b release https://github.com/lammps/lammps.git lammps

# %%
def go_to_lammps_source():
  # %cd lammps
  # %cd src

# %%
def install_lammps_packages():
  list_of_packages_to_install = ['ASPHERE',
                                 'BODY',
                                 'BROWNIAN',
                                 'COLLOID',
                                 'DIELECTRIC',
                                 'DIPOLE',
                                 'DPD-BASIC',
                                 'DPD-MESO',
                                 'DPD-REACT',
                                 'DPD-SMOOTH',
                                 'DRUDE',
                                 'EXTRA-COMMAND',
                                 'EXTRA-COMPUTE',
                                 'EXTRA-DUMP',
                                 'EXTRA-FIX',
                                 'EXTRA-MOLECULE',
                                 'EXTRA-PAIR',
                                 'GRANULAR',
                                 'KSPACE',
                                 'MANYBODY',
                                 'MEAM',
                                 'MOLECULE',
                                 'ORIENT',
                                 'RIGID']

  for package in list_of_packages_to_install:
    # !make yes-{package}
  # !make mpi

# %%
def save_current_build_as_zip():
  # !zip -r -v lammps.zip lammps

# %%
def load_a_previous_build():
  # !unzip /content/drive/'My Drive'/lammps.zip -d /content/

# %%
def prepare_environment():
  import os
  os.environ["OMP_NUM_THREADS"] = "2"
  os.environ["MKL_NUM_THREADS"] = "2"
  os.environ["PATH"] = "/content/lammps/build:"+os.environ["PATH"]
  print("run like ::: !mpirun -np 2 --allow-run-as-root /content/lammps/build/lmp -in /content/lammps/examples/crack/in.crack")

# %% [markdown]
# ---

# %%
go_to_my_drive()

# %%
go_to_my_desktop()

# %%
download_lammps_from_source()

# %%
go_to_lammps_source()

# %%
install_lammps_packages()

# %%
# !make ps

# %%
go_to_my_desktop()

# %%
save_current_build_as_zip()
